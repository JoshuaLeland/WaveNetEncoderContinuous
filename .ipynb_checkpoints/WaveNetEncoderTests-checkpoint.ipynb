# %%
from WaveNetEncoder import WaveNetEncoder
import numpy as np
import torch
import math
import matplotlib.pyplot as plt

# %%
#Generate fake data
numTSteps = 10000
zeropad = 9
length = 10
dt = length / numTSteps
times = np.array([ dt for i in range(numTSteps)])
times = np.cumsum(times)

# %%
signal = np.zeros(numTSteps + zeropad)
signal[zeropad:] = np.cos(2*math.pi*times + math.pi/10) + np.cos(6*math.pi*times + math.pi/10)+ np.sin(25*math.pi*times + math.pi/10)
generated_signal = np.zeros(numTSteps + zeropad)
signal = signal / (np.max(signal) + 0.001)
signalt = torch.tensor(signal, dtype=torch.float).unsqueeze(0).unsqueeze(0)

# %%
plt.plot(signal)

# %%
encoder = WaveNetEncoder(n_layers=10,max_dilation=128,n_residual_channels=3,n_dilated_channels=6, encoding_factor=500, encoding_stride=500)
# Out:
# /Users/joshleland/Desktop/WaveNet/WaveNetEncoder/WaveNetEncoder.py:20: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
#   self.conv.weight, gain=torch.nn.init.calculate_gain(w_init_gain))

# %%
#Test individual layers.
signal = encoder.NCInput(signalt)
signal.size()
# Out:
# torch.Size([1, 3, 10009])

# %%
skip = signal
signal = torch.nn.functional.relu(signal, True)
signal = encoder.dilate_layers[0](signal)
signal.size()
# Out:
# torch.Size([1, 6, 10008])

# %%
signal = torch.nn.functional.relu(signal, True)
signal = encoder.res_layers[0](signal)
length = signal.size(2)
signal.size()
# Out:
# torch.Size([1, 3, 10008])

# %%
skip.size()
# Out:
# torch.Size([1, 3, 10009])

# %%
skip = skip[:,:,-length:]

# %%
skip.size()
# Out:
# torch.Size([1, 3, 10008])

# %%
signal = signal + skip
signal.size()
# Out:
# torch.Size([1, 3, 10008])

# %%
signal = encoder.final_layer(signal)
signal.size()
# Out:
# torch.Size([1, 1, 10008])

# %%
signal = encoder.pooling_layer(signal)
signal.size()
# Out:
# torch.Size([1, 1, 20])

# %%
encoding = encoder(signalt)
encoding.size()
# Out:
# torch.Size([1, 1, 19])
